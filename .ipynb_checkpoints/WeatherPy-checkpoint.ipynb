# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat = []
lng = []
cities = []

#create dataframe to hold info
data_df = pd.DataFrame(columns =["Latitude","Longitude","City","Max Temperature","Humidity","Clouds","Wind Speed"])

# Create a set of random lat and lng combinations
#lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
#lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
#lat_lngs = zip(lats, lngs)

#generate random lat and long combinations
for x in range(0,1200):
    lat.append(np.random.uniform(-90,91))
    lng.append(np.random.uniform(-181,181))

#add random combinations to dataframe
data_df["Latitude"] = lat
data_df["Longitude"] = lng

# Identify nearest city for each lat, lng combination
#not sure what city name is!!
for index,row in data_df.iterrows():
    city = citipy.nearest_city(row["Latitude"], row["Longitude"])
    cities.append(city.city_name)
    
data_df["City"] = cities
    
clean_data = data_df.drop_duplicates("City", keep="first")
    
    # If the city is unique, then add it to a our cities list
#    if city not in cities:
#        cities.append(city)

# Print the city count to confirm sufficient count
len(clean_data)

#test out coordinates in https://www.latlong.net/ - all coordinates match nearby cities!
# Out:
# 503

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
api_key = "1cc185571a2f937159aadcb09eaf4cd6"

temp = []
humidity = []
cloud = []
wind = []

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

#response = requests.get(query_url + "paris").json()
#print(json.dumps(response, indent=4, sort_keys=True))


#need to set counter at 0 so iterrows loop starts at 1 (otherwise, city will start at 2)
counter = 0

print("Beginning data retrieval")
print("---------------------------------------------------------------------")

for index, row in clean_data.iterrows():
    counter += 1
    city = row["City"]
    target_url = query_url + city
    print(f"Processing record {counter} | city name: {city}")
    print(f"{target_url}")
              
    try:
        response = requests.get(target_url).json()
        temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
    except:
        pass
        
#add to dataframe
clean_data["Max Temperature"] = temp
clean_data["Humidity"] = humidity
clean_data["Clouds"] = cloud
clean_data["Wind Speed"] = wind
# Out:
# Beginning data retrieval
# ---------------------------------------------------------------------
# Processing record 1 | city name: ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ushuaia
# Processing record 2 | city name: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=saint-philippe
# Processing record 3 | city name: rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=rikitea
# Processing record 4 | city name: sao joao do piaui
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sao joao do piaui
# Processing record 5 | city name: sabang
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sabang
# Processing record 6 | city name: sur
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sur
# Processing record 7 | city name: illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=illoqqortoormiut
# Processing record 8 | city name: punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=punta arenas
# Processing record 9 | city name: lalmohan
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lalmohan
# Processing record 10 | city name: taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=taolanaro
# Processing record 11 | city name: wanaka
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=wanaka
# Processing record 12 | city name: saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=saleaula
# Processing record 13 | city name: tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tiksi
# Processing record 14 | city name: vaini
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=vaini
# Processing record 15 | city name: filadelfia
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=filadelfia
# Processing record 16 | city name: glendive
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=glendive
# Processing record 17 | city name: hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hermanus
# Processing record 18 | city name: lolua
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lolua
# Processing record 19 | city name: portland
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=portland
# Processing record 20 | city name: hilo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hilo
# Processing record 21 | city name: vagay
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=vagay
# Processing record 22 | city name: lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lavrentiya
# Processing record 23 | city name: khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=khatanga
# Processing record 24 | city name: touros
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=touros
# Processing record 25 | city name: castro
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=castro
# Processing record 26 | city name: mangan
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mangan
# Processing record 27 | city name: mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mahebourg
# Processing record 28 | city name: georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=georgetown
# Processing record 29 | city name: ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ilulissat
# Processing record 30 | city name: lebu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lebu
# Processing record 31 | city name: saint george
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=saint george
# Processing record 32 | city name: haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=haines junction
# Processing record 33 | city name: ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ahipara
# Processing record 34 | city name: santa cruz
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=santa cruz
# Processing record 35 | city name: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ribeira grande
# Processing record 36 | city name: xiaoweizhai
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=xiaoweizhai
# Processing record 37 | city name: tucurui
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tucurui
# Processing record 38 | city name: carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=carnarvon
# Processing record 39 | city name: lhokseumawe
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lhokseumawe
# Processing record 40 | city name: tarudant
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tarudant
# Processing record 41 | city name: altamira
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=altamira
# Processing record 42 | city name: butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=butaritari
# Processing record 43 | city name: halalo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=halalo
# Processing record 44 | city name: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=puerto ayora
# Processing record 45 | city name: bindura
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bindura
# Processing record 46 | city name: san miguelito
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=san miguelito
# Processing record 47 | city name: barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=barentsburg
# Processing record 48 | city name: bluff
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bluff
# Processing record 49 | city name: albany
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=albany
# Processing record 50 | city name: kinsale
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kinsale
# Processing record 51 | city name: jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=jamestown
# Processing record 52 | city name: klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=klaksvik
# Processing record 53 | city name: kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kapaa
# Processing record 54 | city name: upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=upernavik
# Processing record 55 | city name: mpophomeni
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mpophomeni
# Processing record 56 | city name: airai
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=airai
# Processing record 57 | city name: laguna
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=laguna
# Processing record 58 | city name: vicuna
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=vicuna
# Processing record 59 | city name: keuruu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=keuruu
# Processing record 60 | city name: waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=waipawa
# Processing record 61 | city name: tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tsihombe
# Processing record 62 | city name: prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=prince rupert
# Processing record 63 | city name: mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mys shmidta
# Processing record 64 | city name: adrar
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=adrar
# Processing record 65 | city name: batangafo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=batangafo
# Processing record 66 | city name: saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=saskylakh
# Processing record 67 | city name: komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=komsomolskiy
# Processing record 68 | city name: codrington
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=codrington
# Processing record 69 | city name: busselton
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=busselton
# Processing record 70 | city name: batticaloa
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=batticaloa
# Processing record 71 | city name: gunjur
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=gunjur
# Processing record 72 | city name: macusani
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=macusani
# Processing record 73 | city name: cedral
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=cedral
# Processing record 74 | city name: sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sentyabrskiy
# Processing record 75 | city name: coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=coahuayana
# Processing record 76 | city name: nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nanortalik
# Processing record 77 | city name: carmen
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=carmen
# Processing record 78 | city name: naron
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=naron
# Processing record 79 | city name: kieta
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kieta
# Processing record 80 | city name: talaya
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=talaya
# Processing record 81 | city name: pundaguitan
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pundaguitan
# Processing record 82 | city name: kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kavieng
# Processing record 83 | city name: dikson
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=dikson
# Processing record 84 | city name: kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kruisfontein
# Processing record 85 | city name: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=severo-kurilsk
# Processing record 86 | city name: alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=alta floresta
# Processing record 87 | city name: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=chokurdakh
# Processing record 88 | city name: jinsha
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=jinsha
# Processing record 89 | city name: halifax
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=halifax
# Processing record 90 | city name: odweyne
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=odweyne
# Processing record 91 | city name: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=qaanaaq
# Processing record 92 | city name: terrace
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=terrace
# Processing record 93 | city name: cape town
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=cape town
# Processing record 94 | city name: esperance
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=esperance
# Processing record 95 | city name: hobart
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hobart
# Processing record 96 | city name: sundargarh
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sundargarh
# Processing record 97 | city name: grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=grindavik
# Processing record 98 | city name: asau
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=asau
# Processing record 99 | city name: bondo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bondo
# Processing record 100 | city name: lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lagoa
# Processing record 101 | city name: deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=deputatskiy
# Processing record 102 | city name: beboto
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=beboto
# Processing record 103 | city name: isangel
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=isangel
# Processing record 104 | city name: san francisco
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=san francisco
# Processing record 105 | city name: belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=belushya guba
# Processing record 106 | city name: kirkcudbright
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kirkcudbright
# Processing record 107 | city name: gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=gornopravdinsk
# Processing record 108 | city name: sola
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sola
# Processing record 109 | city name: nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nizhneyansk
# Processing record 110 | city name: datong
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=datong
# Processing record 111 | city name: pevek
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pevek
# Processing record 112 | city name: naze
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=naze
# Processing record 113 | city name: port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=port alfred
# Processing record 114 | city name: bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bubaque
# Processing record 115 | city name: new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=new norfolk
# Processing record 116 | city name: atuona
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=atuona
# Processing record 117 | city name: oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=oktyabrskiy
# Processing record 118 | city name: kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kaitangata
# Processing record 119 | city name: avera
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=avera
# Processing record 120 | city name: tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tilichiki
# Processing record 121 | city name: celestun
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=celestun
# Processing record 122 | city name: huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=huarmey
# Processing record 123 | city name: provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=provideniya
# Processing record 124 | city name: okato
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=okato
# Processing record 125 | city name: santa rosalia
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=santa rosalia
# Processing record 126 | city name: grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=grand river south east
# Processing record 127 | city name: new ulm
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=new ulm
# Processing record 128 | city name: teeli
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=teeli
# Processing record 129 | city name: aflu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=aflu
# Processing record 130 | city name: pemba
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pemba
# Processing record 131 | city name: sitka
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sitka
# Processing record 132 | city name: trincomalee
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=trincomalee
# Processing record 133 | city name: shelbyville
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=shelbyville
# Processing record 134 | city name: kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kangaatsiaq
# Processing record 135 | city name: kindu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kindu
# Processing record 136 | city name: moron
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=moron
# Processing record 137 | city name: chern
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=chern
# Processing record 138 | city name: buala
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=buala
# Processing record 139 | city name: mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mount isa
# Processing record 140 | city name: pochutla
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pochutla
# Processing record 141 | city name: victoria
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=victoria
# Processing record 142 | city name: ziro
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ziro
# Processing record 143 | city name: deniliquin
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=deniliquin
# Processing record 144 | city name: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=arraial do cabo
# Processing record 145 | city name: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nikolskoye
# Processing record 146 | city name: barrow
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=barrow
# Processing record 147 | city name: lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lompoc
# Processing record 148 | city name: goderich
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=goderich
# Processing record 149 | city name: broome
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=broome
# Processing record 150 | city name: khomeynishahr
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=khomeynishahr
# Processing record 151 | city name: yerkoy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=yerkoy
# Processing record 152 | city name: galesong
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=galesong
# Processing record 153 | city name: port blair
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=port blair
# Processing record 154 | city name: college
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=college
# Processing record 155 | city name: norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=norman wells
# Processing record 156 | city name: yurya
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=yurya
# Processing record 157 | city name: lircay
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lircay
# Processing record 158 | city name: vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=vaitupu
# Processing record 159 | city name: petropavlovka
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=petropavlovka
# Processing record 160 | city name: fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=fort nelson
# Processing record 161 | city name: east london
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=east london
# Processing record 162 | city name: kampong cham
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kampong cham
# Processing record 163 | city name: daru
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=daru
# Processing record 164 | city name: austin
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=austin
# Processing record 165 | city name: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hithadhoo
# Processing record 166 | city name: bintulu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bintulu
# Processing record 167 | city name: longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=longyearbyen
# Processing record 168 | city name: pangody
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pangody
# Processing record 169 | city name: roald
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=roald
# Processing record 170 | city name: umm lajj
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=umm lajj
# Processing record 171 | city name: cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=cherskiy
# Processing record 172 | city name: kailua
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kailua
# Processing record 173 | city name: ulladulla
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ulladulla
# Processing record 174 | city name: nobeoka
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nobeoka
# Processing record 175 | city name: nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nantucket
# Processing record 176 | city name: kamennomostskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kamennomostskiy
# Processing record 177 | city name: aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=aklavik
# Processing record 178 | city name: leh
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=leh
# Processing record 179 | city name: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tuktoyaktuk
# Processing record 180 | city name: bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bathsheba
# Processing record 181 | city name: luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=luderitz
# Processing record 182 | city name: ternate
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ternate
# Processing record 183 | city name: neuquen
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=neuquen
# Processing record 184 | city name: malakal
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=malakal
# Processing record 185 | city name: kahului
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kahului
# Processing record 186 | city name: flinders
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=flinders
# Processing record 187 | city name: cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=cidreira
# Processing record 188 | city name: attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=attawapiskat
# Processing record 189 | city name: nanakuli
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nanakuli
# Processing record 190 | city name: rudsar
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=rudsar
# Processing record 191 | city name: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=port elizabeth
# Processing record 192 | city name: vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=vila velha
# Processing record 193 | city name: ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ponta do sol
# Processing record 194 | city name: hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hamilton
# Processing record 195 | city name: kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kalmunai
# Processing record 196 | city name: port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=port hedland
# Processing record 197 | city name: burns lake
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=burns lake
# Processing record 198 | city name: samusu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=samusu
# Processing record 199 | city name: mataura
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mataura
# Processing record 200 | city name: port shepstone
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=port shepstone
# Processing record 201 | city name: jalu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=jalu
# Processing record 202 | city name: poum
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=poum
# Processing record 203 | city name: barra patuca
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=barra patuca
# Processing record 204 | city name: samsun
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=samsun
# Processing record 205 | city name: sanarate
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sanarate
# Processing record 206 | city name: solovetskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=solovetskiy
# Processing record 207 | city name: morant bay
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=morant bay
# Processing record 208 | city name: redlands
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=redlands
# Processing record 209 | city name: breisach
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=breisach
# Processing record 210 | city name: yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=yellowknife
# Processing record 211 | city name: nanfeng
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nanfeng
# Processing record 212 | city name: praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=praia da vitoria
# Processing record 213 | city name: quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=quatre cocos
# Processing record 214 | city name: marcona
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=marcona
# Processing record 215 | city name: usinsk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=usinsk
# Processing record 216 | city name: along
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=along
# Processing record 217 | city name: manokwari
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=manokwari
# Processing record 218 | city name: diamantino
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=diamantino
# Processing record 219 | city name: saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=saint anthony
# Processing record 220 | city name: rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=rio grande
# Processing record 221 | city name: hofn
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hofn
# Processing record 222 | city name: sohag
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sohag
# Processing record 223 | city name: yambio
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=yambio
# Processing record 224 | city name: bertoua
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bertoua
# Processing record 225 | city name: coracora
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=coracora
# Processing record 226 | city name: santa barbara
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=santa barbara
# Processing record 227 | city name: kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kavaratti
# Processing record 228 | city name: tessalit
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tessalit
# Processing record 229 | city name: mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mar del plata
# Processing record 230 | city name: zapolyarnyy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=zapolyarnyy
# Processing record 231 | city name: iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=iqaluit
# Processing record 232 | city name: inongo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=inongo
# Processing record 233 | city name: dingle
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=dingle
# Processing record 234 | city name: port moresby
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=port moresby
# Processing record 235 | city name: soyo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=soyo
# Processing record 236 | city name: avarua
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=avarua
# Processing record 237 | city name: lethbridge
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lethbridge
# Processing record 238 | city name: kendal
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kendal
# Processing record 239 | city name: ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ketchikan
# Processing record 240 | city name: muli
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=muli
# Processing record 241 | city name: biak
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=biak
# Processing record 242 | city name: salalah
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=salalah
# Processing record 243 | city name: karatau
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=karatau
# Processing record 244 | city name: hovd
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hovd
# Processing record 245 | city name: rudnogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=rudnogorsk
# Processing record 246 | city name: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tasiilaq
# Processing record 247 | city name: ossora
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ossora
# Processing record 248 | city name: chake chake
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=chake chake
# Processing record 249 | city name: cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=cockburn town
# Processing record 250 | city name: samarai
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=samarai
# Processing record 251 | city name: ryotsu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ryotsu
# Processing record 252 | city name: te anau
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=te anau
# Processing record 253 | city name: nefteyugansk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nefteyugansk
# Processing record 254 | city name: miles city
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=miles city
# Processing record 255 | city name: salekhard
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=salekhard
# Processing record 256 | city name: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bredasdorp
# Processing record 257 | city name: sawtell
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sawtell
# Processing record 258 | city name: nueve de julio
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nueve de julio
# Processing record 259 | city name: wagar
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=wagar
# Processing record 260 | city name: pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pangnirtung
# Processing record 261 | city name: viedma
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=viedma
# Processing record 262 | city name: yuanping
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=yuanping
# Processing record 263 | city name: bilma
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bilma
# Processing record 264 | city name: tres coroas
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tres coroas
# Processing record 265 | city name: westport
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=westport
# Processing record 266 | city name: zhangye
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=zhangye
# Processing record 267 | city name: benghazi
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=benghazi
# Processing record 268 | city name: porto novo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=porto novo
# Processing record 269 | city name: ozernovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ozernovskiy
# Processing record 270 | city name: nguiu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nguiu
# Processing record 271 | city name: kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kirakira
# Processing record 272 | city name: fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=fortuna
# Processing record 273 | city name: tidore
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tidore
# Processing record 274 | city name: tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tumannyy
# Processing record 275 | city name: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=guerrero negro
# Processing record 276 | city name: sfantu gheorghe
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sfantu gheorghe
# Processing record 277 | city name: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bambous virieux
# Processing record 278 | city name: anshun
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=anshun
# Processing record 279 | city name: hokitika
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hokitika
# Processing record 280 | city name: moree
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=moree
# Processing record 281 | city name: fernley
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=fernley
# Processing record 282 | city name: waddan
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=waddan
# Processing record 283 | city name: boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=boa vista
# Processing record 284 | city name: talara
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=talara
# Processing record 285 | city name: sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sao felix do xingu
# Processing record 286 | city name: chapais
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=chapais
# Processing record 287 | city name: evensk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=evensk
# Processing record 288 | city name: ayolas
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ayolas
# Processing record 289 | city name: amuntai
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=amuntai
# Processing record 290 | city name: sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sobolevo
# Processing record 291 | city name: acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=acapulco
# Processing record 292 | city name: urumqi
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=urumqi
# Processing record 293 | city name: alofi
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=alofi
# Processing record 294 | city name: kargasok
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kargasok
# Processing record 295 | city name: dzhusaly
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=dzhusaly
# Processing record 296 | city name: vallenar
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=vallenar
# Processing record 297 | city name: mrirt
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mrirt
# Processing record 298 | city name: dongli
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=dongli
# Processing record 299 | city name: the valley
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=the valley
# Processing record 300 | city name: novi iskar
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=novi iskar
# Processing record 301 | city name: kyzyl-suu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kyzyl-suu
# Processing record 302 | city name: edd
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=edd
# Processing record 303 | city name: vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=vestmannaeyjar
# Processing record 304 | city name: hvolsvollur
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hvolsvollur
# Processing record 305 | city name: byron bay
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=byron bay
# Processing record 306 | city name: zheleznodorozhnyy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=zheleznodorozhnyy
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=faanui
# Processing record 427 | city name: micheweni
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=micheweni
# Processing record 428 | city name: phan thiet
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=phan thiet
# Processing record 429 | city name: grand centre
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=grand centre
# Processing record 430 | city name: hirara
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hirara
# Processing record 431 | city name: henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=henties bay
# Processing record 432 | city name: mwinilunga
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mwinilunga
# Processing record 433 | city name: kenai
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kenai
# Processing record 434 | city name: harbour breton
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=harbour breton
# Processing record 435 | city name: ipueiras
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ipueiras
# Processing record 436 | city name: kodinsk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kodinsk
# Processing record 437 | city name: marawi
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=marawi
# Processing record 438 | city name: trebukhiv
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=trebukhiv
# Processing record 439 | city name: lebedyn
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lebedyn
# Processing record 440 | city name: maykain
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=maykain
# Processing record 441 | city name: mackenzie
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mackenzie
# Processing record 442 | city name: ranot
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ranot
# Processing record 443 | city name: malartic
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=malartic
# Processing record 444 | city name: saryshagan
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=saryshagan
# Processing record 445 | city name: cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=cayenne
# Processing record 446 | city name: kingstown
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kingstown
# Processing record 447 | city name: talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=talnakh
# Processing record 448 | city name: kollam
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kollam
# Processing record 449 | city name: cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=cap malheureux
# Processing record 450 | city name: brae
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=brae
# Processing record 451 | city name: quelimane
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=quelimane
# Processing record 452 | city name: bela pod bezdezem
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bela pod bezdezem
# Processing record 453 | city name: egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=egvekinot
# Processing record 454 | city name: sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sao filipe
# Processing record 455 | city name: prudyanka
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=prudyanka
# Processing record 456 | city name: solnechnyy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=solnechnyy
# Processing record 457 | city name: caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=caravelas
# Processing record 458 | city name: abdanan
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=abdanan
# Processing record 459 | city name: okha
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=okha
# Processing record 460 | city name: bakchar
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=bakchar
# Processing record 461 | city name: tekeli
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tekeli
# Processing record 462 | city name: parabel
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=parabel
# Processing record 463 | city name: itoman
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=itoman
# Processing record 464 | city name: wangjing
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=wangjing
# Processing record 465 | city name: ngukurr
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ngukurr
# Processing record 466 | city name: gizo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=gizo
# Processing record 467 | city name: ust-omchug
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ust-omchug
# Processing record 468 | city name: uvat
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=uvat
# Processing record 469 | city name: kalabo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=kalabo
# Processing record 470 | city name: tabiauea
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tabiauea
# Processing record 471 | city name: campiglia marittima
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=campiglia marittima
# Processing record 472 | city name: burnie
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=burnie
# Processing record 473 | city name: esil
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=esil
# Processing record 474 | city name: pangai
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pangai
# Processing record 475 | city name: beloha
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=beloha
# Processing record 476 | city name: izumo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=izumo
# Processing record 477 | city name: lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=lorengau
# Processing record 478 | city name: beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=beringovskiy
# Processing record 479 | city name: vila
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=vila
# Processing record 480 | city name: pokhara
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pokhara
# Processing record 481 | city name: pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pangkalanbuun
# Processing record 482 | city name: wuwei
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=wuwei
# Processing record 483 | city name: nalut
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nalut
# Processing record 484 | city name: eureka
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=eureka
# Processing record 485 | city name: hanko
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=hanko
# Processing record 486 | city name: urdzhar
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=urdzhar
# Processing record 487 | city name: nakamura
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nakamura
# Processing record 488 | city name: vardo
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=vardo
# Processing record 489 | city name: saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=saldanha
# Processing record 490 | city name: brainerd
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=brainerd
# Processing record 491 | city name: pine bluff
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=pine bluff
# Processing record 492 | city name: iki-burul
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=iki-burul
# Processing record 493 | city name: santa rosa
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=santa rosa
# Processing record 494 | city name: veraval
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=veraval
# Processing record 495 | city name: grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=grand gaube
# Processing record 496 | city name: mazyr
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mazyr
# Processing record 497 | city name: tocopilla
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tocopilla
# Processing record 498 | city name: zavodoukovsk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=zavodoukovsk
# Processing record 499 | city name: waingapu
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=waingapu
# Processing record 500 | city name: iquitos
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=iquitos
# Processing record 501 | city name: sechura
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=sechura
# Processing record 502 | city name: nowe miasto lubawskie
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=nowe miasto lubawskie
# Processing record 503 | city name: tateyama
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=tateyama
# Processing record 504 | city name: alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=alice springs
# Processing record 505 | city name: thomasville
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=thomasville
# Processing record 506 | city name: mecca
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=mecca
# Processing record 507 | city name: port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=port hardy
# Processing record 508 | city name: agdam
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=agdam
# Processing record 509 | city name: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=leningradskiy
# Processing record 510 | city name: ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=ugoofaaru
# Processing record 511 | city name: dagana
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=dagana
# Processing record 512 | city name: thompson
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=thompson
# Processing record 513 | city name: petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=petropavlovsk-kamchatskiy
# Processing record 514 | city name: uyskoye
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=uyskoye
# Processing record 515 | city name: maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=maniitsoq
# Processing record 516 | city name: derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=derzhavinsk
# Processing record 517 | city name: inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=1cc185571a2f937159aadcb09eaf4cd6&units=imperial&q=inhambane
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f66eb49b8e8a> in <module>
#      38
#      39 #add to dataframe
# ---> 40 clean_data["Max Temperature"] = temp
#      41 clean_data["Humidity"] = humidity
#      42 clean_data["Clouds"] = cloud
#
# ~\AnacondaNew\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~\AnacondaNew\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ~\AnacondaNew\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
#    3390             # turn me into an ndarray
# -> 3391             value = _sanitize_index(value, self.index, copy=False)
#    3392             if not isinstance(value, (np.ndarray, Index)):
#    3393                 if isinstance(value, list) and len(value) > 0:
#
# ~\AnacondaNew\lib\site-packages\pandas\core\series.py in _sanitize_index(data, index, copy)
#    3999
#    4000     if len(data) != len(index):
# -> 4001         raise ValueError('Length of values does not match length of ' 'index')
#    4002
#    4003     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#export dataframe to csv
clean_data.to_csv("CityData.csv")

# %%
clean_data.head()
# Out:
#     Latitude   Longitude            City Max Temperature Humidity Clouds  \
# 0 -43.446953  -50.457377   mar del plata             NaN      NaN    NaN
# 1  38.741345  164.365964  severo-kurilsk             NaN      NaN    NaN
# 2   5.127274  -41.565056        cururupu             NaN      NaN    NaN
# 3 -76.001340   -7.894394       cape town             NaN      NaN    NaN
# 4  74.171222   36.620478        tumannyy             NaN      NaN    NaN
#
#   Wind Speed
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(clean_data["Latitude"], clean_data["Max Temperature"], marker="o", facecolors="green", edgecolors="black")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(clean_data["Latitude"], clean_data["Humidity"], marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_data["Latitude"], clean_data["Clouds"], marker="o", facecolors="red", edgecolors="black")
plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_data["Latitude"], clean_data["Wind Speed"], marker="o", facecolors="black")
plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
